# %% [markdown]
# <a href="https://colab.research.google.com/github/bhadreshpsavani/OCR_using_TesseatactLib_Project/blob/master/OCRusingTesseractWithYellowText.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...

# %%
import pytesseract
import shutil
import os
import random
import cv2
from google.colab.patches import cv2_imshow
try:
    from PIL import Image
except ImportError:
    import Image

# %% [markdown]
# ## Open Image:
# ![img](/yellow_text.jpg)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e5c4f1c5-46a7-4343-a229-cac12b9f82db" name="files[]" multiple disabled />
#      <output id="result-e5c4f1c5-46a7-4343-a229-cac12b9f82db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2.jpg

# %%
extractedInformation = pytesseract.image_to_string(Image.open('./yellow_text.jpg'))

# %%
print(extractedInformation)
# Out:
# Hi this is Bhadresh Savani.
#
# | work in NLP,

# %% [markdown]
# ## Lets Do Some Img Preprocessing

# %%
originalImage = cv2.imread('yellow_text.jpg')

# %%
grayImage = cv2.cvtColor(originalImage, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(originalImage)
# Out:
# <PIL.Image.Image image mode=RGB size=958x1280 at 0x7FC77790CE50>

# %%
cv2_imshow(grayImage)
# Out:
# <PIL.Image.Image image mode=L size=958x1280 at 0x7FC77E42FE10>

# %% [markdown]
# ## Lets Try Thresholding and get Blacka and White Image

# %%
(thresh, blackAndWhiteImage) = cv2.threshold(grayImage, 230, 255, cv2.THRESH_BINARY)
cv2_imshow(blackAndWhiteImage)
print(thresh)
# Out:
# <PIL.Image.Image image mode=L size=958x1280 at 0x7FC76E96C410>
# 230.0

# %%
extractedInformation = pytesseract.image_to_string(blackAndWhiteImage)

# %%
print(extractedInformation)
# Out:
# Hi this is Bhadresh Savani.
# | work in NLP,
#
# | learning Data Science. | wanted to
# contribute in Opensource Softwares
# but iam not getting enough time
# Due to Personal Projects and
#
# Online Courses
